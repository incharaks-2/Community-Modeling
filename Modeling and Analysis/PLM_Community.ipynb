# %%
#Setting up PyCoMo
#Install PyCoMo using pip or conda first in suitable conda environment (mine is in base environment) using anaconda prompt 
#we are going to import all the packages we need.
from pathlib import Path
import sys
import cobra
import os

# %%
#Importing PyCoMo
#As PyCoMo is currently only available as a local package, the direct path to the package directory needs to be used on import.
path_root = r"C:\Users\incha\anaconda3\Lib\site-packages\pycomo\__init__.py"  # Change path according to your PyCoMo location
sys.path.append(str(path_root))
import pycomo
pycomo.configure_logger(level="info")
# Out:
# 2025-05-04 19:35:18,979 - pycomo - INFO - Logger initialized.
# 2025-05-04 19:35:18,987 - pycomo - INFO - Process Pool Logger initialized.
# 2025-05-04 19:35:18,987 - pycomo - INFO - Utils Logger initialized.
# 2025-05-04 19:35:18,993 - pycomo - INFO - Multiprocess Logger initialized.
# 2025-05-04 19:35:18,995 - pycomo - INFO - Log level set to info

# %%
# create two cobra models from sbml (change the path according to where the models are located)
#Fp = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\FP_AHD_Medium.xml")
Pc = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\PC_AHD_Medium.xml")
Ms = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\MS_AHD_Medium.xml")
Lr = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\LR_AHD_Medium.xml")

# create Single Organism Models from cobra models
#FP = pycomo.SingleOrganismModel(Fp, "Fp")
PC = pycomo.SingleOrganismModel(Pc, "Pc")
MS = pycomo.SingleOrganismModel(Ms, "Ms")
LR = pycomo.SingleOrganismModel(Lr, "Lr")

# create Community Model from Single Organism Models
Model = pycomo.CommunityModel([PC, MS, LR], name = "PLM_community")
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2660067
# Academic license 2660067 - for non-commercial use only - registered to t2___@students.iitmandi.ac.in
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpnznd6emv.lp
# Reading time = 0.04 seconds
# : 1621 rows, 3724 columns, 12098 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp4tkw8u7b.lp
# Reading time = 0.01 seconds
# : 743 rows, 1380 columns, 5986 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmplv43zfvj.lp
# Reading time = 0.02 seconds
# : 1312 rows, 2582 columns, 11182 nonzeros

# %%
Model.model
# Out:
# 2025-05-04 19:36:16,896 - pycomo - INFO - No community model generated yet. Generating now:
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpagjc55fh.lp
# Reading time = 0.03 seconds
# : 1621 rows, 3724 columns, 12098 nonzeros
# 2025-05-04 19:36:21,120 - pycomo - INFO - Identified biomass reaction from objective: biomass525
# 2025-05-04 19:36:21,122 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpm3mw__li.lp
# Reading time = 0.03 seconds
# : 743 rows, 1380 columns, 5986 nonzeros
# 2025-05-04 19:37:00,584 - pycomo - INFO - Identified biomass reaction from objective: biomass537
# 2025-05-04 19:37:00,600 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp8_xo80er.lp
# Reading time = 0.04 seconds
# : 1877 rows, 3646 columns, 12602 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpxrls0_w8.lp
# Reading time = 0.09 seconds
# : 1312 rows, 2582 columns, 11182 nonzeros
# 2025-05-04 19:37:16,921 - pycomo - INFO - Identified biomass reaction from objective: bio1
# 2025-05-04 19:37:16,923 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpjabv09o2.lp
# Reading time = 0.11 seconds
# : 3335 rows, 6628 columns, 23048 nonzeros
# 2025-05-04 19:37:52,369 - pycomo - WARNING - Warning: not wrongly formatted metabolite formula in metabolites of reaction Lr_HMR_9520_Lr_c
# 2025-05-04 19:37:52,399 - pycomo - WARNING - Not all reactions in the model are mass and charge balanced. To check which reactions are imbalanced, please run the get_unbalanced_reactions method of this CommunityModel object
# 2025-05-04 19:37:52,399 - pycomo - INFO - Generated community model.
# <Model PLM_community at 0x273e69d76e0>

# %%
Model.convert_to_fixed_abundance()
abundances = {"Pc": 0.391, "Ms": 4.57E-05, "Lr":0.002938}
# Apply the abundances
Model.apply_fixed_abundance(abundances)
# Out:
# 2025-05-04 19:38:03,020 - pycomo - WARNING - Warning: Abundances do not sum up to 1. Correction will be applied: {'Pc': 0.391, 'Ms': 4.57e-05, 'Lr': 0.002938}
# 2025-05-04 19:38:03,022 - pycomo - INFO - Correction applied. New abundances are:
# {'Pc': 0.9924268440547159, 'Ms': 0.00011599464647902946, 'Lr': 0.007457161298805001}

# %%
Model.summary()
# Out:
# <h3>Objective</h3><p>1.0 community_biomass = 17.48088873432672</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>_7a_czp_medium</td>
#       <td>EX__7a_czp_medium</td>
#       <td>202.2</td>
#       <td>15</td>
#       <td>55.17%</td>
#     </tr>
#     <tr>
#       <td>acald_medium</td>
#       <td>EX_acald_medium</td>
#       <td>0.3739</td>
#       <td>2</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>ade_medium</td>
#       <td>EX_ade_medium</td>
#       <td>0.01915</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>adn_medium</td>
#       <td>EX_adn_medium</td>
#       <td>5.235</td>
#       <td>10</td>
#       <td>0.95%</td>
#     </tr>
#     <tr>
#       <td>ala_L_medium</td>
#       <td>EX_ala_L_medium</td>
#       <td>0.4111</td>
#       <td>3</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>alagln_medium</td>
#       <td>EX_alagln_medium</td>
#       <td>0.001563</td>
#       <td>8</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>alaglu_medium</td>
#       <td>EX_alaglu_medium</td>
#       <td>0.00354</td>
#       <td>8</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>alahis_medium</td>
#       <td>EX_alahis_medium</td>
#       <td>0.0001878</td>
#       <td>9</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>alathr_medium</td>
#       <td>EX_alathr_medium</td>
#       <td>0.0005001</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>anzp_medium</td>
#       <td>EX_anzp_medium</td>
#       <td>0.03046</td>
#       <td>15</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>asn_L_medium</td>
#       <td>EX_asn_L_medium</td>
#       <td>0.02618</td>
#       <td>4</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>asp_L_medium</td>
#       <td>EX_asp_L_medium</td>
#       <td>0.4065</td>
#       <td>4</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>ca2_medium</td>
#       <td>EX_ca2_medium</td>
#       <td>0.1359</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cgly_medium</td>
#       <td>EX_cgly_medium</td>
#       <td>0.0005723</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>chor_medium</td>
#       <td>EX_chor_medium</td>
#       <td>0.0006501</td>
#       <td>10</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_medium</td>
#       <td>EX_cl_medium</td>
#       <td>0.1359</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_medium</td>
#       <td>EX_cobalt2_medium</td>
#       <td>0.1359</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>csn_medium</td>
#       <td>EX_csn_medium</td>
#       <td>0.02722</td>
#       <td>4</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_medium</td>
#       <td>EX_cu2_medium</td>
#       <td>0.1359</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cys_L_medium</td>
#       <td>EX_cys_L_medium</td>
#       <td>0.007163</td>
#       <td>3</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cytd_medium</td>
#       <td>EX_cytd_medium</td>
#       <td>70.26</td>
#       <td>9</td>
#       <td>11.51%</td>
#     </tr>
#     <tr>
#       <td>dad_2_medium</td>
#       <td>EX_dad_2_medium</td>
#       <td>0.2038</td>
#       <td>10</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>dcyt_medium</td>
#       <td>EX_dcyt_medium</td>
#       <td>10.27</td>
#       <td>9</td>
#       <td>1.68%</td>
#     </tr>
#     <tr>
#       <td>dgsn_medium</td>
#       <td>EX_dgsn_medium</td>
#       <td>0.2038</td>
#       <td>10</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>fe2_medium</td>
#       <td>EX_fe2_medium</td>
#       <td>0.1367</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_medium</td>
#       <td>EX_fe3_medium</td>
#       <td>0.1355</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fol_medium</td>
#       <td>EX_fol_medium</td>
#       <td>0.001211</td>
#       <td>19</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fru_medium</td>
#       <td>EX_fru_medium</td>
#       <td>1.163</td>
#       <td>6</td>
#       <td>0.13%</td>
#     </tr>
#     <tr>
#       <td>glu_L_medium</td>
#       <td>EX_glu_L_medium</td>
#       <td>45.19</td>
#       <td>5</td>
#       <td>4.11%</td>
#     </tr>
#     <tr>
#       <td>glyasn_medium</td>
#       <td>EX_glyasn_medium</td>
#       <td>0.0004759</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glyc3p_medium</td>
#       <td>EX_glyc3p_medium</td>
#       <td>0.1437</td>
#       <td>3</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>glyleu_medium</td>
#       <td>EX_glyleu_medium</td>
#       <td>0.06093</td>
#       <td>8</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>glymet_medium</td>
#       <td>EX_glymet_medium</td>
#       <td>0.02063</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glytyr_medium</td>
#       <td>EX_glytyr_medium</td>
#       <td>0.01573</td>
#       <td>11</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>gsn_medium</td>
#       <td>EX_gsn_medium</td>
#       <td>2.292</td>
#       <td>10</td>
#       <td>0.42%</td>
#     </tr>
#     <tr>
#       <td>gua_medium</td>
#       <td>EX_gua_medium</td>
#       <td>0.01947</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2_medium</td>
#       <td>EX_h2_medium</td>
#       <td>0.07872</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>his_L_medium</td>
#       <td>EX_his_L_medium</td>
#       <td>0.01033</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hxan_medium</td>
#       <td>EX_hxan_medium</td>
#       <td>7.528</td>
#       <td>5</td>
#       <td>0.68%</td>
#     </tr>
#     <tr>
#       <td>ile_L_medium</td>
#       <td>EX_ile_L_medium</td>
#       <td>0.04262</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>indole_medium</td>
#       <td>EX_indole_medium</td>
#       <td>0.0001118</td>
#       <td>8</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>k_medium</td>
#       <td>EX_k_medium</td>
#       <td>0.1359</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>lys_L_medium</td>
#       <td>EX_lys_L_medium</td>
#       <td>5.787</td>
#       <td>6</td>
#       <td>0.63%</td>
#     </tr>
#     <tr>
#       <td>met_L_medium</td>
#       <td>EX_met_L_medium</td>
#       <td>4.541</td>
#       <td>5</td>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <td>mg2_medium</td>
#       <td>EX_mg2_medium</td>
#       <td>0.1359</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_medium</td>
#       <td>EX_mn2_medium</td>
#       <td>0.1359</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mqn7_medium</td>
#       <td>EX_mqn7_medium</td>
#       <td>0.0008073</td>
#       <td>46</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nac_medium</td>
#       <td>EX_nac_medium</td>
#       <td>0.0007956</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_medium</td>
#       <td>EX_o2_medium</td>
#       <td>299</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>phe_L_medium</td>
#       <td>EX_phe_L_medium</td>
#       <td>0.02014</td>
#       <td>9</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pheme_medium</td>
#       <td>EX_pheme_medium</td>
#       <td>0.0004037</td>
#       <td>34</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_medium</td>
#       <td>EX_pi_medium</td>
#       <td>23.79</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pnto_R_medium</td>
#       <td>EX_pnto_R_medium</td>
#       <td>0.0008308</td>
#       <td>9</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pro_L_medium</td>
#       <td>EX_pro_L_medium</td>
#       <td>0.02447</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ptrc_medium</td>
#       <td>EX_ptrc_medium</td>
#       <td>0.0004037</td>
#       <td>4</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pydx_medium</td>
#       <td>EX_pydx_medium</td>
#       <td>0.1355</td>
#       <td>8</td>
#       <td>0.02%</t

# %%
Model.model.optimize()
# Out:
# <Solution 17.481 at 0x273869fa840>

# %%
Model.save(r"C:\Users\incha\MTdata\Indian_Community\PLM.xml")

# %%
import pandas as pd
fva = Model.run_fva(reactions=Model.model.reactions, fraction_of_optimum=0.9, loopless=True, processes=4)

# Save to Excel
fva.to_excel(r"C:\Users\incha\MTdata\Indian_Community\PLM_loopless_FVA.xlsx")
# Out:
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpu2m79k_6.lp
# Reading time = 0.16 seconds
# : 10102 rows, 20542 columns, 67060 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp11k8tso1.lp
# Reading time = 0.12 seconds
# : 4186 rows, 8704 columns, 31562 nonzeros
# 2025-05-04 21:11:55,685 - pycomo - WARNING - Find loops step timed out for rxn Pc__12PPD_Stex
# 2025-05-04 21:11:59,464 - pycomo - INFO - Processed 0.23% of find loops steps
# 2025-05-04 21:12:01,240 - pycomo - INFO - Processed 0.46% of find loops steps
# 2025-05-04 21:12:02,651 - pycomo - INFO - Processed 0.69% of find loops steps
# 2025-05-04 21:12:04,312 - pycomo - INFO - Processed 0.92% of find loops steps
# 2025-05-04 21:12:05,504 - pycomo - INFO - Processed 1.15% of find loops steps
# 2025-05-04 21:12:07,152 - pycomo - INFO - Processed 1.38% of find loops steps
# 2025-05-04 21:12:08,729 - pycomo - INFO - Processed 1.61% of find loops steps
# 2025-05-04 21:12:10,036 - pycomo - INFO - Processed 1.84% of find loops steps
# 2025-05-04 21:12:11,135 - pycomo - INFO - Processed 2.07% of find loops steps
# 2025-05-04 21:12:12,541 - pycomo - INFO - Processed 2.3% of find loops steps
# 2025-05-04 21:12:13,665 - pycomo - INFO - Processed 2.53% of find loops steps
# 2025-05-04 21:12:14,961 - pycomo - INFO - Processed 2.76% of find loops steps
# 2025-05-04 21:12:15,989 - pycomo - INFO - Processed 2.99% of find loops steps
# 2025-05-04 21:12:17,224 - pycomo - INFO - Processed 3.22% of find loops steps
# 2025-05-04 21:12:18,241 - pycomo - INFO - Processed 3.45% of find loops steps
# 2025-05-04 21:12:19,489 - pycomo - INFO - Processed 3.68% of find loops steps
# 2025-05-04 21:12:20,331 - pycomo - INFO - Processed 3.91% of find loops steps
# 2025-05-04 21:12:21,569 - pycomo - INFO - Processed 4.14% of find loops steps
# 2025-05-04 21:12:22,831 - pycomo - INFO - Processed 4.37% of find loops steps
# 2025-05-04 21:12:23,966 - pycomo - INFO - Processed 4.6% of find loops steps
# 2025-05-04 21:12:25,308 - pycomo - INFO - Processed 4.83% of find loops steps
# 2025-05-04 21:12:26,796 - pycomo - INFO - Processed 5.06% of find loops steps
# 2025-05-04 21:12:28,185 - pycomo - INFO - Processed 5.28% of find loops steps
# 2025-05-04 21:12:29,367 - pycomo - INFO - Processed 5.51% of find loops steps
# 2025-05-04 21:12:30,507 - pycomo - INFO - Processed 5.74% of find loops steps
# 2025-05-04 21:12:31,690 - pycomo - INFO - Processed 5.97% of find loops steps
# 2025-05-04 21:12:32,787 - pycomo - INFO - Processed 6.2% of find loops steps
# 2025-05-04 21:12:34,014 - pycomo - INFO - Processed 6.43% of find loops steps
# 2025-05-04 21:12:35,102 - pycomo - INFO - Processed 6.66% of find loops steps
# 2025-05-04 21:12:36,320 - pycomo - INFO - Processed 6.89% of find loops steps
# 2025-05-04 21:12:37,499 - pycomo - INFO - Processed 7.12% of find loops steps
# 2025-05-04 21:12:38,552 - pycomo - INFO - Processed 7.35% of find loops steps
# 2025-05-04 21:12:40,096 - pycomo - INFO - Processed 7.58% of find loops steps
# 2025-05-04 21:12:41,085 - pycomo - INFO - Processed 7.81% of find loops steps
# 2025-05-04 21:12:42,279 - pycomo - INFO - Processed 8.04% of find loops steps
# 2025-05-04 21:12:43,247 - pycomo - INFO - Processed 8.27% of find loops steps
# 2025-05-04 21:12:44,441 - pycomo - INFO - Processed 8.5% of find loops steps
# 2025-05-04 21:12:45,602 - pycomo - INFO - Processed 8.73% of find loops steps
# 2025-05-04 21:12:46,741 - pycomo - INFO - Processed 8.96% of find loops steps
# 2025-05-04 21:12:48,079 - pycomo - INFO - Processed 9.19% of find loops steps
# 2025-05-04 21:12:49,853 - pycomo - INFO - Processed 9.42% of find loops steps
# 2025-05-04 21:12:51,553 - pycomo - INFO - Processed 9.65% of find loops steps
# 2025-05-04 21:12:53,071 - pycomo - INFO - Processed 9.88% of find loops steps
# 2025-05-04 21:12:54,673 - pycomo - INFO - Processed 10.11% of find loops steps
# 2025-05-04 21:12:55,765 - pycomo - INFO - Processed 10.34% of find loops steps
# 2025-05-04 21:12:57,169 - pycomo - INFO - Processed 10.57% of find loops steps
# 2025-05-04 21:12:58,351 - pycomo - INFO - Processed 10.8% of find loops steps
# 2025-05-04 21:12:59,486 - pycomo - INFO - Processed 11.03% of find loops steps
# 2025-05-04 21:13:00,665 - pycomo - INFO - Processed 11.26% of find loops steps
# 2025-05-04 21:13:01,938 - pycomo - INFO - Processed 11.49% of find loops steps
# 2025-05-04 21:13:03,397 - pycomo - INFO - Processed 11.72% of find loops steps
# 2025-05-04 21:13:04,696 - pycomo - INFO - Processed 11.95% of find loops steps
# 2025-05-04 21:13:06,034 - pycomo - INFO - Processed 12.18% of find loops steps
# 2025-05-04 21:13:07,311 - pycomo - INFO - Processed 12.41% of find loops steps
# 2025-05-04 21:13:08,388 - pycomo - INFO - Processed 12.64% of find loops steps
# 2025-05-04 21:13:09,610 - pycomo - INFO - Processed 12.87% of find loops steps
# 2025-05-04 21:13:10,904 - pycomo - INFO - Processed 13.1% of find loops steps
# 2025-05-04 21:13:12,290 - pycomo - INFO - Processed 13.33% of find loops steps
# 2025-05-04 21:13:13,321 - pycomo - INFO - Processed 13.56% of find loops steps
# 2025-05-04 21:13:14,729 - pycomo - INFO - Processed 13.79% of find loops steps
# 2025-05-04 21:13:15,984 - pycomo - INFO - Processed 14.02% of find loops steps
# 2025-05-04 21:13:17,303 - pycomo - INFO - Processed 14.25% of find loops steps
# 2025-05-04 21:13:18,402 - pycomo - INFO - Processed 14.48% of find loops steps
# 2025-05-04 21:13:19,488 - pycomo - INFO - Processed 14.71% of find loops steps
# 2025-05-04 21:13:20,552 - pycomo - INFO - Processed 14.94% of find loops steps
# 2025-05-04 21:13:21,565 - pycomo - INFO - Processed 15.17% of find loops steps
# 2025-05-04 21:13:22,771 - pycomo - INFO - Processed 15.4% of find loops steps
# 2025-05-04 21:13:23,855 - pycomo - INFO - Processed 15.62% of find loops steps
# 2025-05-04 21:13:25,147 - pycomo - INFO - Processed 15.85% of find loops steps
# 2025-05-04 21:13:26,370 - pycomo - INFO - Processed 16.08% of find loops steps
# 2025-05-04 21:13:27,466 - pycomo - INFO - Processed 16.31% of find loops steps
# 2025-05-04 21:13:28,738 - pycomo - INFO - Processed 16.54% of find loops steps
# 2025-05-04 21:13:29,718 - pycomo - INFO - Processed 16.77% of find loops steps
# 2025-05-04 21:13:30,870 - pycomo - INFO - Processed 17.0% of find loops steps
# 2025-05-04 21:13:32,005 - pycomo - INFO - Processed 17.23% of find loops steps
# 2025-05-04 21:13:33,074 - pycomo - INFO - Processed 17.46% of find loops steps
# 2025-05-04 21:13:34,614 - pycomo - INFO - Processed 17.69% of find loops steps
# 2025-05-04 21:13:35,742 - pycomo - INFO - Processed 17.92% of find loops steps
# 2025-05-04 21:13:37,082 - pycomo - INFO - Processed 18.15% of find loops steps
# 2025-05-04 21:13:38,211 - pycomo - INFO - Processed 18.38% of find loops steps
# 2025-05-04 21:13:39,414 - pycomo - INFO - Processed 18.61% of find loops steps
# 2025-05-04 21:13:40,406 - pycomo - INFO - Processed 18.84% of find loops steps
# 2025-05-04 21:13:41,655 - pycomo - INFO - Processed 19.07% of find loops steps
# 2025-05-04 21:13:43,013 - pycomo - INFO - Processed 19.3% of find loops steps
# 2025-05-04 21:13:44,129 - pycomo - INFO - Processed 19.53% of find loops steps
# 2025-05-04 21:13:45,589 - pycomo - INFO - Processed 19.76% of find loops steps
# 2025-05-04 21:13:46,790 - pycomo - INFO - Processed 19.99% of find loops steps
# 2025-05-04 21:13:47,907 - pycomo - INFO - Processed 20.22% of find loops steps
# 2025-05-04 21:13:49,126 - pycomo - INFO - Processed 20.45% of find loops steps
# 2025-05-04 21:13:50,873 - pycomo - INFO - Processed 20.68% of find loops steps
# 2025-05-04 21:13:52,083 - pycomo - INFO - Processed 20.91% of find loops steps
# 2025-05-04 21:13:53,165 - pycomo - INFO - Processed 21.14% of find loops steps
# 2025-05-04 21:13:54,428 - pycomo - INFO - Processed 21.37% of find loops steps
# 2025-05-04 21:13:55,660 - pycomo - INFO - Processed 21.6% of find loops steps
# 2025-05-04 21:13:56,720 - pycomo - INFO - Processed 21.83% of find loops steps
# 2025-05-04 21:13:58,075 - pycomo - INFO - Processed 22.06% of find loops steps
# 2025-05-04 21:13:59,266 - pycomo - INFO - Processed 22.29% of find loops steps
# 2025-05-04 21:14:00,515 - pycomo - INFO - Processed 22.52% of find loops steps
# 2025-05-04 21:14:01,680 - pycomo - INFO - Processed 22.75% of find loops steps
# 2025-05-04 21:14:03,032 - pycomo - INFO - Processed 22.98% of find loops steps
# 2025-05-04 21:14:04,303 - pycomo - INFO - Processed 23.21% of find loops steps
# 2025-05-04 21:14:05,388 - pycomo - INFO - Processed 23.44% of find loops steps
# 2025-05-04 21:14:06,905 - pycomo - INFO - Processed 23.67% of find loops steps
# 2025-05-04 21:14:08,091 - pycomo - INFO - Processed 23.9% of find loops steps
# 2025-05-04 21:14:09,469 - pycomo - INFO - Processed 24.13% of find loops steps
# 2025-05-04 21:14:11,288 - pycomo - INFO - Processed 24.36% of find loops steps
# 2025-05-04 21:14:12,398 - pycomo - INFO - Processed 24.59% of find loops steps
# 2025-05-04 21:14:13,714 - pycomo - INFO - Processed 24.82% of find loops steps
# 2025-05-04 21:14:15,109 - pycomo - INFO - Processed 25.05% of find loops steps
# 2025-05-04 21:14:16,871 - pycomo - INFO - Processed 25.28% of find loops steps
# 2025-05-04 21:14:18,100 - pycomo - INFO - Processed 25.51% of find loops steps
# 2025-05-04 21:14:19,695 - pycomo - INFO - Processed 25.74% of find loops steps
# 2025-05-04 21:14:21,428 - pycomo - INFO - Processed 25.97% of find loops steps
# 2025-05-04 21:14:22,712 - pycomo - INFO - Processed 26.19% of find loops steps
# 2025-05-04 21:14:23,790 - pycomo - INFO - Processed 26.42% of find loops steps
# 2025-05-04 21:14:25,658 - pycomo - INFO - Processed 26.65% of find loops steps
# 2025-05-04 21:14:26,913 - pycomo - INFO - Processed 26.88% of find loops steps
# 2025-05-04 21:14:28,593 - pycomo - INFO - Processed 27.11% of find loops steps
# 2025-05-04 21:14:30,057 - pycomo - INFO - Processed 27.34% of find loops steps
# 2025-05-04 21:14:31,450 - pycomo - INFO - Processed 27.57% of find loops steps
# 2025-05-04 21:14:33,642 - pycomo - INFO - Processed 27.8% of find loops steps
# 2025-05-04 21:14:36,933 - pycomo - INFO - Processed 28.03% of find loops steps
# 2025-05-04 21:14:38,951 - pycomo - INFO - Processed 28.26% of find loops steps
# 2025-05-04 21:14:41,589 - pycomo - INFO - Processed 28.49% of find loops steps
# 2025-05-04 21:14:43,542 - pycomo - INFO - Processed 28.72% of find loops steps
# 2025-05-04 21:14:45,607 - pycomo - INFO - Processed 28.95% of find loops steps
# 2025-05-04 21:14:47,841 - pycomo - INFO - Processed 29.18% of find loops steps
# 2025-05-04 21:14:49,670 - pycomo - INFO - Processed 29.41% of find loops steps
# 2025-05-04 21:14:52,497 - pycomo - INFO - Processed 29.64% of find loops steps
# 2025-05-04 21:14:54,620 - pycomo - INFO - Processed 29.87% of find loops steps
# 2025-05-04 21:14:58,429 - pycomo - INFO - Processed 30.1% of find loops steps
# 2025-05-04 21:15:01,129 - pycomo - INFO - Processed 30.33% of find loops steps
# 2025-05-04 21:15:03,270 - pycomo - INFO - Processed 30.56% of find loops steps
# 2025-05-04 21:15:05,958 - pycomo - INFO - Processed 30.79% of find loops steps
# 2025-05-04 21:15:07,836 - pycomo - INFO - Processed 31.02% of find loops steps
# 2025-05-04 21:15:10,799 - pycomo - INFO - Processed 31.25% of find loops steps
# 2025-05-04 21:15:13,722 - pycomo - INFO - Processed 31.48% of find loops steps
# 2025-05-04 21:15:16,730 - pycomo - INFO - Processed 31.71% of find loops steps
# 2025-05-04 21:15:20,023 - pycomo - INFO - Processed 31.94% of find loops steps
# 2025-05-04 21:15:22,788 - pycomo - INFO - Processed 32.17% of find loops steps
# 2025-05-04 21:15:26,565 - pycomo - INFO - Processed 32.4% of find loops steps
# 2025-05-04 21:15:29,942 - pycomo - INFO - Processed 32.63% of find loops steps
# 2025-05-04 21:15:32,795 - pycomo - INFO - Processed 32.86% of find loops steps
# 2025-05-04 21:15:35,658 - pycomo - INFO - Processed 33.09% of find loops steps
# 2025-05-04 21:15:38,089 - pycomo - INFO - Processed 33.32% of find loops steps
# 2025-05-04 21:15:39,899 - pycomo - INFO - Processed 33.55% of find loops steps
# 2025-05-04 21:15:42,165 - pycomo - INFO - Processed 33.78% of find loops steps
# 2025-05-04 21:15:45,252 - pycomo - INFO - Processed 34.01% of find loops steps
# 2025-05-04 21:15:47,095 - pycomo - INFO - Processed 34.24% of find loops steps
# 2025-05-04 21:15:50,238 - pycomo - INFO - Processed 34.47% of find loops steps
# 2025-05-04 21:15:52,218 - pycomo - INFO - Processed 34.7% of find loops steps
# 2025-05-04 21:15:54,812 - pycomo - INFO - Processed 34.93% of find loops steps
# 2025-05-04 21:15:57,465 - pycomo - INFO - Processed 35.16% of find loops steps
# 2025-05-04 21:16:00,549 - pycomo - INFO - Processed 35.39% of find loops steps
# 2025-05-04 21:16:03,892 - pycomo - INFO - Processed 35.62% of find loops steps
# 2025-05-04 21:16:06,256 - pycomo - INFO - Processed 35.85% of find loops steps
# 2025-05-04 21:16:08,230 - pycomo - INFO - Processed 36.08% of find loops steps
# 2025-05-04 21:16:10,951 - pycomo - INFO - Processed 36.31% of find loops steps
# 2025-05-04 21:16:13,467 - pycomo - INFO - Processed 36.53% of find loops steps
# 2025-05-04 21:16:15,224 - pycomo - INFO - Processed 36.76% of find loops steps
# 2025-05-04 21:16:18,775 - pycomo - INFO - Processed 36.99% of find loops steps
# 2025-05-04 21:16:21,513 - pycomo - INFO - Processed 37.22% of find loops steps
# 2025-05-04 21:16:23,863 - pycomo - INFO - Processed 37.45% of find loops steps
# 2025-05-04 21:16:25,746 - pycomo - INFO - Processed 37.68% of find loops steps
# 2025-05-04 21:16:27,672 - pycomo - INFO - Processed 37.91% of find loops steps
# 2025-05-04 21:16:30,856 - pycomo - INFO - Processed 38.14% of find loops steps
# 2025-05-04 21:16:32,537 - pycomo - INFO - Processed 38.37% of find loops steps
# 2025-05-04 21:16:35,205 - pycomo - INFO - Processed 38.6% of find loops steps
# 2025-05-04 21:16:38,222 - pycomo - INFO - Processed 38.83% of find loops steps
# 2025-05-04 21:16:39,993 - pycomo - INFO - Processed 39.06% of find loops steps
# 2025-05-04 21:16:42,575 - pycomo - INFO - Processed 39.29% of find loops steps
# 2025-05-04 21:16:44,365 - pycomo - INFO - Processed 39.52% of find loops steps
# 2025-05-04 21:16:47,366 - pycomo - INFO - Processed 39.75% of find loops steps
# 2025-05-04 21:16:49,861 - pycomo - INFO - Processed 39.98% of find loops steps
# 2025-05-04 21:16:51,130 - pycomo - INFO - Processed 40.21% of find loops steps
# 2025-05-04 21:16:53,545 - pycomo - INFO - Processed 40.44% of find loops steps
# 2025-05-04 21:16:55,567 - pycomo - INFO - Processed 40.67% of find loops steps
# 2025-05-04 21:16:57,872 - pycomo - INFO - Processed 40.9% of find loops steps
# 2025-05-04 21:17:00,760 - pycomo - INFO - Processed 41.13% of find loops steps
# 2025-05-04 21:17:03,310 - pycomo - INFO - Processed 41.36% of find loops steps
# 2025-05-04 21:17:05,894 - pycomo - INFO - Processed 41.59% of find loops steps
# 2025-05-04 21:17:08,559 - pycomo - INFO - Processed 41.82% of find loops steps
# 2025-05-04 21:17:10,733 - pycomo - INFO - Processed 42.05% of find loops steps
# 2025-05-04 21:17:13,381 - pycomo - INFO - Processed 42.28% of find loops steps
# 2025-05-04 21:17:15,378 - pycomo - INFO - Processed 42.51% of find loops steps
# 2025-05-04 21:17:17,964 - pycomo - INFO - Processed 42.74% of find loops steps
# 2025-05-04 21:17:20,102 - pycomo - INFO - Processed 42.97% of find loops steps
# 2025-05-04 21:17:22,268 - pycomo - INFO - Processed 43.2% of find loops steps
# 2025-05-04 21:17:23,701 - pycomo - INFO - Processed 43.43% of find loops steps
# 2025-05-04 21:17:25,120 - pycomo - INFO - Processed 43.66% of find loops steps
# 2025-05-04 21:17:27,364 - pycomo - INFO - Processed 43.89% of find loops steps
# 2025-05-04 21:17:30,363 - pycomo - INFO - Processed 44.12% of find loops steps
# 2025-05-04 21:17:33,633 - pycomo - INFO - Processed 44.35% of find loops steps
# 2025-05-04 21:17:36,017 - pycomo - INFO - Processed 44.58% of find loops steps
# 2025-05-04 21:17:38,191 - pycomo - INFO - Processed 44.81% of find loops steps
# 2025-05-04 21:17:40,540 - pycomo - INFO - Processed 45.04% of find loops steps
# 2025-05-04 21:17:43,210 - pycomo - INFO - Processed 45.27% of find loops steps
# 2025-05-04 21:17:45,887 - pycomo - INFO - Processed 45.5% of find loops steps
# 2025-05-04 21:17:48,475 - pycomo - INFO - Processed 45.73% of find loops steps
# 2025-05-04 21:17:50,829 - pycomo - INFO - Processed 45.96% of find loops steps
# 2025-05-04 21:17:52,678 - pycomo - INFO - Processed 46.19% of find loops steps
# 2025-05-04 21:17:54,805 - pycomo - INFO - Processed 46.42% of find loops steps
# 2025-05-04 21:17:57,192 - pycomo - INFO - Processed 46.65% of find loops steps
# 2025-05-04 21:17:58,723 - pycomo - INFO - Processed 46.88% of find loops steps
# 2025-05-04 21:18:01,595 - pycomo - INFO - Processed 47.1% of find loops steps
# 2025-05-04 21:18:03,618 - pycomo - INFO - Processed 47.33% of find loops steps
# 2025-05-04 21:18:07,158 - pycomo - INFO - Processed 47.56% of find loops steps
# 2025-05-04 21:18:09,155 - pycomo - INFO - Processed 47.79% of find loops steps
# 2025-05-04 21:18:13,000 - pycomo - INFO - Processed 48.02% of find loops steps
# 2025-05-04 21:18:15,336 - pycomo - INFO - Processed 48.25% of find loops steps
# 2025-05-04 21:18:17,652 - pycomo - INFO - Processed 48.48% of find loops steps
# 2025-05-04 21:18:20,870 - pycomo - INFO - Processed 48.71% of find loops steps
# 2025-05-04 21:18:23,584 - pycomo - INFO - Processed 48.94% of find loops steps
# 2025-05-04 21:18:25,617 - pycomo - INFO - Processed 49.17% of find loops steps
# 2025-05-04 21:18:28,370 - pycomo - INFO - Processed 49.4% of find loops steps
# 2025-05-04 21:18:30,981 - pycomo - INFO - Processed 49.63% of find loops steps
# 2025-05-04 21:18:32,919 - pycomo - INFO - Processed 49.86% of find loops steps
# 2025-05-04 21:18:34,785 - pycomo - INFO - Processed 50.09% of find loops steps
# 2025-05-04 21:18:36,902 - pycomo - INFO - Processed 50.32% of find loops steps
# 2025-05-04 21:18:39,219 - pycomo - INFO - Processed 50.55% of find loops steps
# 2025-05-04 21:18:41,573 - pycomo - INFO - Processed 50.78% of find loops steps
# 2025-05-04 21:18:44,766 - pycomo - INFO - Processed 51.01% of find loops steps
# 2025-05-04 21:18:48,881 - pycomo - INFO - Processed 51.24% of find loops steps
# 2025-05-04 21:18:50,183 - pycomo - INFO - Processed 51.47% of find loops steps
# 2025-05-04 21:18:52,863 - pycomo - INFO - Processed 51.7% of find loops steps
# 2025-05-04 21:18:53,903 - pycomo - INFO - Processed 51.93% of find loops steps
# 2025-05-04 21:18:55,439 - pycomo - INFO - Processed 52.16% of find loops steps
# 2025-05-04 21:18:56,513 - pycomo - INFO - Processed 52.39% of find loops steps
# 2025-05-04 21:18:57,787 - pycomo - INFO - Processed 52.62% of find loops steps
# 2025-05-04 21:18:58,819 - pycomo - INFO - Processed 52.85% of find loops steps
# 2025-05-04 21:19:00,208 - pycomo - INFO - Processed 53.08% of find loops steps
# 2025-05-04 21:19:01,903 - pycomo - INFO - Processed 53.31% of find loops steps
# 2025-05-04 21:19:03,279 - pycomo - INFO - Processed 53.54% of find loops steps
# 2025-05-04 21:19:04,598 - pycomo - INFO - Processed 53.77% of find loops steps
# 2025-05-04 21:19:05,913 - pycomo - INFO - Processed 54.0% of find loops steps
# 2025-05-04 21:19:07,083 - pycomo - INFO - Processed 54.23% of find loops steps
# 2025-05-04 21:19:08,282 - pycomo - INFO - Processed 54.46% of find loops steps
# 2025-05-04 21:19:09,698 - pycomo - INFO - Processed 54.69% of find loops steps
# 2025-05-04 21:19:10,678 - pycomo - INFO - Processed 54.92% of find loops steps
# 2025-05-04 21:19:11,908 - pycomo - INFO - Processed 55.15% of find loops steps
# 2025-05-04 21:19:13,168 - pycomo - INFO - Processed 55.38% of find loops steps
# 2025-05-04 21:19:14,308 - pycomo - INFO - Processed 55.61% of find loops steps
# 2025-05-04 21:19:15,755 - pycomo - INFO - Processed 55.84% of find loops steps
# 2025-05-04 21:19:16,583 - pycomo - INFO - Processed 56.07% of find loops steps
# 2025-05-04 21:19:17,976 - pycomo - INFO - Processed 56.3% of find loops steps
# 2025-05-04 21:19:19,179 - pycomo - INFO - Processed 56.53% of find loops steps
# 2025-05-04 21:19:20,642 - pycomo - INFO - Processed 56.76% of find loops steps
# 2025-05-04 21:19:21,655 - pycomo - INFO - Processed 56.99% of find loops steps
# 2025-05-04 21:19:23,059 - pycomo - INFO - Processed 57.22% of find loops steps
# 2025-05-04 21:19:24,361 - pycomo - INFO - Processed 57.44% of find loops steps
# 2025-05-04 21:19:25,498 - pycomo - INFO - Processed 57.67% of find loops steps
# 2025-05-04 21:19:26,673 - pycomo - INFO - Processed 57.9% of find loops steps
# 2025-05-04 21:19:28,180 - pycomo - INFO - Processed 58.13% of find loops steps
# 2025-05-04 21:19:29,545 - pycomo - INFO - Processed 58.36% of find loops steps
# 2025-05-04 21:19:30,657 - pycomo - INFO - Processed 58.59% of find loops steps
# 2025-05-04 21:19:31,988 - pycomo - INFO - Processed 58.82% of find loops steps
# 2025-05-04 21:19:33,530 - pycomo - INFO - Processed 59.05% of find loops steps
# 2025-05-04 21:19:34,426 - pycomo - INFO - Processed 59.28% of find loops steps
# 2025-05-04 21:19:35,770 - pycomo - INFO - Processed 59.51% of find loops steps
# 2025-05-04 21:19:37,074 - pycomo - INFO - Processed 59.74% of find loops steps
# 2025-05-04 21:19:38,001 - pycomo - INFO - Processed 59.97% of find loops steps
# 2025-05-04 21:19:39,428 - pycomo - INFO - Processed 60.2% of find loops steps
# 2025-05-04 21:19:40,252 - pycomo - INFO - Processed 60.43% of find loops steps
# 2025-05-04 21:19:41,412 - pycomo - INFO - Processed 60.66% of find loops steps
# 2025-05-04 21:19:42,638 - pycomo - INFO - Processed 60.89% of find loops steps
# 2025-05-04 21:19:44,017 - pycomo - INFO - Processed 61.12% of find loops steps
# 2025-05-04 21:19:45,066 - pycomo - INFO - Processed 61.35% of find loops steps
# 2025-05-04 21:19:46,377 - pycomo - INFO - Processed 61.58% of find loops steps
# 2025-05-04 21:19:47,509 - pycomo - INFO - Processed 61.81% of find loops steps
# 2025-05-04 21:19:48,842 - pycomo - INFO - Processed 62.04% of find loops steps
# 2025-05-04 21:19:50,042 - pycomo - INFO - Processed 62.27% of find loops steps
# 2025-05-04 21:19:51,285 - pycomo - INFO - Processed 62.5% of find loops steps
# 2025-05-04 21:19:52,451 - pycomo - INFO - Processed 62.73% of find loops steps
# 2025-05-04 21:19:54,053 - pycomo - INFO - Processed 62.96% of find loops steps
# 2025-05-04 21:19:55,121 - pycomo - INFO - Processed 63.19% of find loops steps
# 2025-05-04 21:19:56,169 - pycomo - INFO - Processed 63.42% of find loops steps
# 2025-05-04 21:19:57,471 - pycomo - INFO - Processed 63.65% of find loops steps
# 2025-05-04 21:19:58,636 - pycomo - INFO - Processed 63.88% of find loops steps
# 2025-05-04 21:19:59,855 - pycomo - INFO - Processed 64.11% of find loops steps
# 2025-05-04 21:20:00,964 - pycomo - INFO - Processed 64.34% of find loops steps
# 2025-05-04 21:20:02,172 - pycomo - INFO - Processed 64.57% of find loops steps
# 2025-05-04 21:20:03,686 - pycomo - INFO - Processed 64.8% of find loops steps
# 2025-05-04 21:20:04,664 - pycomo - INFO - Processed 65.03% of find loops steps
# 2025-05-04 21:20:05,868 - pycomo - INFO - Processed 65.26% of find loops steps
# 2025-05-04 21:20:07,037 - pycomo - INFO - Processed 65.49% of find loops steps
# 2025-05-04 21:20:08,317 - pycomo - INFO - Processed 65.72% of find loops steps
# 2025-05-04 21:20:09,351 - pycomo - INFO - Processed 65.95% of find loops steps
# 2025-05-04 21:20:10,520 - pycomo - INFO - Processed 66.18% of find loops steps
# 2025-05-04 21:20:11,685 - pycomo - INFO - Processed 66.41% of find loops steps
# 2025-05-04 21:20:12,659 - pycomo - INFO - Processed 66.64% of find loops steps
# 2025-05-04 21:20:13,756 - pycomo - INFO - Processed 66.87% of find loops steps
# 2025-05-04 21:20:15,031 - pycomo - INFO - Processed 67.1% of find loops steps
# 2025-05-04 21:20:16,110 - pycomo - INFO - Processed 67.33% of find loops steps
# 2025-05-04 21:20:17,331 - pycomo - INFO - Processed 67.56% of find loops steps
# 2025-05-04 21:20:18,275 - pycomo - INFO - Processed 67.78% of find loops steps
# 2025-05-04 21:20:19,558 - pycomo - INFO - Processed 68.01% of find loops steps
# 2025-05-04 21:20:20,862 - pycomo - INFO - Processed 68.24% of find loops steps
# 2025-05-04 21:20:21,747 - pycomo - INFO - Processed 68.47% of find loops steps
# 2025-05-04 21:20:22,896 - pycomo - INFO - Processed 68.7% of find loops steps
# 2025-05-04 21:20:24,125 - pycomo - INFO - Processed 68.93% of find loops steps
# 2025-05-04 21:20:25,454 - pycomo - INFO - Processed 69.16% of find loops steps
# 2025-05-04 21:20:26,585 - pycomo - INFO - Processed 69.39% of find loops steps
# 2025-05-04 21:20:27,893 - pycomo - INFO - Processed 69.62% of find loops steps
# 2025-05-04 21:20:29,001 - pycomo - INFO - Processed 69.85% of find loops steps
# 2025-05-04 21:20:30,383 - pycomo - INFO - Processed 70.08% of find loops steps
# 2025-05-04 21:20:31,538 - pycomo - INFO - Processed 70.31% of find loops steps
# 2025-05-04 21:20:32,810 - pycomo - INFO - Processed 70.54% of find loops steps
# 2025-05-04 21:20:34,182 - pycomo - INFO - Processed 70.77% of find loops steps
# 2025-05-04 21:20:35,246 - pycomo - INFO - Processed 71.0% of find loops steps
# 2025-05-04 21:20:36,516 - pycomo - INFO - Processed 71.23% of find loops steps
# 2025-05-04 21:20:37,686 - pycomo - INFO - Processed 71.46% of find loops steps
# 2025-05-04 21:20:38,937 - pycomo - INFO - Processed 71.69% of find loops steps
# 2025-05-04 21:20:40,007 - pycomo - INFO - Processed 71.92% of find loops steps
# 2025-05-04 21:20:41,619 - pycomo - INFO - Processed 72.15% of find loops steps
# 2025-05-04 21:20:42,688 - pycomo - INFO - Processed 72.38% of find loops steps
# 2025-05-04 21:20:44,192 - pycomo - INFO - Processed 72.61% of find loops steps
# 2025-05-04 21:20:45,340 - pycomo - INFO - Processed 72.84% of find loops steps
# 2025-05-04 21:20:46,714 - pycomo - INFO - Processed 73.07% of find loops steps
# 2025-05-04 21:20:47,811 - pycomo - INFO - Processed 73.3% of find loops steps
# 2025-05-04 21:20:49,054 - pycomo - INFO - Processed 73.53% of find loops steps
# 2025-05-04 21:20:50,430 - pycomo - INFO - Processed 73.76% of find loops steps
# 2025-05-04 21:20:51,772 - pycomo - INFO - Processed 73.99% of find loops steps
# 2025-05-04 21:20:52,795 - pycomo - INFO - Processed 74.22% of find loops steps
# 2025-05-04 21:20:54,373 - pycomo - INFO - Processed 74.45% of find loops steps
# 2025-05-04 21:20:55,638 - pycomo - INFO - Processed 74.68% of find loops steps
# 2025-05-04 21:20:57,011 - pycomo - INFO - Processed 74.91% of find loops steps
# 2025-05-04 21:20:58,146 - pycomo - INFO - Processed 75.14% of find loops steps
# 2025-05-04 21:20:59,694 - pycomo - INFO - Processed 75.37% of find loops steps
# 2025-05-04 21:21:00,681 - pycomo - INFO - Processed 75.6% of find loops steps
# 2025-05-04 21:21:01,908 - pycomo - INFO - Processed 75.83% of find loops steps
# 2025-05-04 21:21:02,923 - pycomo - INFO - Processed 76.06% of find loops steps
# 2025-05-04 21:21:04,066 - pycomo - INFO - Processed 76.29% of find loops steps
# 2025-05-04 21:21:05,234 - pycomo - INFO - Processed 76.52% of find loops steps
# 2025-05-04 21:21:06,532 - pycomo - INFO - Processed 76.75% of find loops steps
# 2025-05-04 21:21:07,730 - pycomo - INFO - Processed 76.98% of find loops steps
# 2025-05-04 21:21:08,985 - pycomo - INFO - Processed 77.21% of find loops steps
# 2025-05-04 21:21:10,440 - pycomo - INFO - Processed 77.44% of find loops steps
# 2025-05-04 21:21:12,048 - pycomo - INFO - Processed 77.67% of find loops steps
# 2025-05-04 21:21:13,216 - pycomo - INFO - Processed 77.9% of find loops steps
# 2025-05-04 21:21:14,608 - pycomo - INFO - Processed 78.12% of find loops steps
# 2025-05-04 21:21:15,716 - pycomo - INFO - Processed 78.35% of find loops steps
# 2025-05-04 21:21:16,915 - pycomo - INFO - Processed 78.58% of find loops steps
# 2025-05-04 21:21:18,445 - pycomo - INFO - Processed 78.81% of find loops steps
# 2025-05-04 21:21:19,457 - pycomo - INFO - Processed 79.04% of find loops steps
# 2025-05-04 21:21:20,938 - pycomo - INFO - Processed 79.27% of find loops steps
# 2025-05-04 21:21:22,134 - pycomo - INFO - Processed 79.5% of find loops steps
# 2025-05-04 21:21:24,056 - pycomo - INFO - Processed 79.73% of find loops steps
# 2025-05-04 21:21:24,913 - pycomo - INFO - Processed 79.96% of find loops steps
# 2025-05-04 21:21:26,211 - pycomo - INFO - Processed 80.19% of find loops steps
# 2025-05-04 21:21:27,846 - pycomo - INFO - Processed 80.42% of find loops steps
# 2025-05-04 21:21:29,101 - pycomo - INFO - Processed 80.65% of find loops steps
# 2025-05-04 21:21:30,290 - pycomo - INFO - Processed 80.88% of find loops steps
# 2025-05-04 21:21:31,912 - pycomo - INFO - Processed 81.11% of find loops steps
# 2025-05-04 21:21:33,564 - pycomo - INFO - Processed 81.34% of find loops steps
# 2025-05-04 21:21:35,226 - pycomo - INFO - Processed 81.57% of find loops steps
# 2025-05-04 21:21:36,657 - pycomo - INFO - Processed 81.8% of find loops steps
# 2025-05-04 21:21:38,199 - pycomo - INFO - Processed 82.03% of find loops steps
# 2025-05-04 21:21:39,473 - pycomo - INFO - Processed 82.26% of find loops steps
# 2025-05-04 21:21:41,168 - pycomo - INFO - Processed 82.49% of find loops steps
# 2025-05-04 21:21:42,516 - pycomo - INFO - Processed 82.72% of find loops steps
# 2025-05-04 21:21:43,434 - pycomo - INFO - Processed 82.95% of find loops steps
# 2025-05-04 21:21:44,682 - pycomo - INFO - Processed 83.18% of find loops steps
# 2025-05-04 21:21:46,204 - pycomo - INFO - Processed 83.41% of find loops steps
# 2025-05-04 21:21:47,334 - pycomo - INFO - Processed 83.64% of find loops steps
# 2025-05-04 21:21:48,654 - pycomo - INFO - Processed 83.87% of find loops steps
# 2025-05-04 21:21:49,788 - pycomo - INFO - Processed 84.1% of find loops steps
# 2025-05-04 21:21:51,127 - pycomo - INFO - Processed 84.33% of find loops steps
# 2025-05-04 21:21:52,267 - pycomo - INFO - Processed 84.56% of find loops steps
# 2025-05-04 21:21:53,644 - pycomo - INFO - Processed 84.79% of find loops steps
# 2025-05-04 21:21:54,686 - pycomo - INFO - Processed 85.02% of find loops steps
# 2025-05-04 21:21:56,167 - pycomo - INFO - Processed 85.25% of find loops steps
# 2025-05-04 21:21:57,467 - pycomo - INFO - Processed 85.48% of find loops steps
# 2025-05-04 21:21:58,771 - pycomo - INFO - Processed 85.71% of find loops steps
# 2025-05-04 21:21:59,830 - pycomo - INFO - Processed 85.94% of find loops steps
# 2025-05-04 21:22:01,209 - pycomo - INFO - Processed 86.17% of find loops steps
# 2025-05-04 21:22:02,354 - pycomo - INFO - Processed 86.4% of find loops steps
# 2025-05-04 21:22:03,439 - pycomo - INFO - Processed 86.63% of find loops steps
# 2025-05-04 21:22:04,753 - pycomo - INFO - Processed 86.86% of find loops steps
# 2025-05-04 21:22:06,029 - pycomo - INFO - Processed 87.09% of find loops steps
# 2025-05-04 21:22:07,245 - pycomo - INFO - Processed 87.32% of find loops steps
# 2025-05-04 21:22:08,777 - pycomo - INFO - Processed 87.55% of find loops steps
# 2025-05-04 21:22:09,726 - pycomo - INFO - Processed 87.78% of find loops steps
# 2025-05-04 21:22:10,910 - pycomo - INFO - Processed 88.01% of find loops steps
# 2025-05-04 21:22:11,824 - pycomo - INFO - Processed 88.24% of find loops steps
# 2025-05-04 21:22:13,061 - pycomo - INFO - Processed 88.47% of find loops steps
# 2025-05-04 21:22:14,040 - pycomo - INFO - Processed 88.69% of find loops steps
# 2025-05-04 21:22:15,404 - pycomo - INFO - Processed 88.92% of find loops steps
# 2025-05-04 21:22:16,414 - pycomo - INFO - Processed 89.15% of find loops steps
# 2025-05-04 21:22:17,568 - pycomo - INFO - Processed 89.38% of find loops steps
# 2025-05-04 21:22:18,763 - pycomo - INFO - Processed 89.61% of find loops steps
# 2025-05-04 21:22:20,090 - pycomo - INFO - Processed 89.84% of find loops steps
# 2025-05-04 21:22:21,144 - pycomo - INFO - Processed 90.07% of find loops steps
# 2025-05-04 21:22:22,282 - pycomo - INFO - Processed 90.3% of find loops steps
# 2025-05-04 21:22:23,866 - pycomo - INFO - Processed 90.53% of find loops steps
# 2025-05-04 21:22:24,929 - pycomo - INFO - Processed 90.76% of find loops steps
# 2025-05-04 21:22:26,286 - pycomo - INFO - Processed 90.99% of find loops steps
# 2025-05-04 21:22:27,499 - pycomo - INFO - Processed 91.22% of find loops steps
# 2025-05-04 21:22:29,127 - pycomo - INFO - Processed 91.45% of find loops steps
# 2025-05-04 21:22:30,421 - pycomo - INFO - Processed 91.68% of find loops steps
# 2025-05-04 21:22:31,652 - pycomo - INFO - Processed 91.91% of find loops steps
# 2025-05-04 21:22:32,860 - pycomo - INFO - Processed 92.14% of find loops steps
# 2025-05-04 21:22:33,788 - pycomo - INFO - Processed 92.37% of find loops steps
# 2025-05-04 21:22:35,118 - pycomo - INFO - Processed 92.6% of find loops steps
# 2025-05-04 21:22:36,501 - pycomo - INFO - Processed 92.83% of find loops steps
# 2025-05-04 21:22:37,845 - pycomo - INFO - Processed 93.06% of find loops steps
# 2025-05-04 21:22:39,248 - pycomo - INFO - Processed 93.29% of find loops steps
# 2025-05-04 21:22:40,523 - pycomo - INFO - Processed 93.52% of find loops steps
# 2025-05-04 21:22:41,598 - pycomo - INFO - Processed 93.75% of find loops steps
# 2025-05-04 21:22:42,934 - pycomo - INFO - Processed 93.98% of find loops steps
# 2025-05-04 21:22:44,219 - pycomo - INFO - Processed 94.21% of find loops steps
# 2025-05-04 21:22:45,210 - pycomo - INFO - Processed 94.44% of find loops steps
# 2025-05-04 21:22:46,761 - pycomo - INFO - Processed 94.67% of find loops steps
# 2025-05-04 21:22:47,582 - pycomo - INFO - Processed 94.9% of find loops steps
# 2025-05-04 21:22:48,748 - pycomo - INFO - Processed 95.13% of find loops steps
# 2025-05-04 21:22:49,890 - pycomo - INFO - Processed 95.36% of find loops steps
# 2025-05-04 21:22:50,984 - pycomo - INFO - Processed 95.59% of find loops steps
# 2025-05-04 21:22:52,135 - pycomo - INFO - Processed 95.82% of find loops steps
# 2025-05-04 21:22:53,095 - pycomo - INFO - Processed 96.05% of find loops steps
# 2025-05-04 21:22:54,449 - pycomo - INFO - Processed 96.28% of find loops steps
# 2025-05-04 21:22:55,862 - pycomo - INFO - Processed 96.51% of find loops steps
# 2025-05-04 21:22:57,359 - pycomo - INFO - Processed 96.74% of find loops steps
# 2025-05-04 21:22:58,612 - pycomo - INFO - Processed 96.97% of find loops steps
# 2025-05-04 21:23:00,008 - pycomo - INFO - Processed 97.2% of find loops steps
# 2025-05-04 21:23:01,067 - pycomo - INFO - Processed 97.43% of find loops steps
# 2025-05-04 21:23:02,188 - pycomo - INFO - Processed 97.66% of find loops steps
# 2025-05-04 21:23:03,219 - pycomo - INFO - Processed 97.89% of find loops steps
# 2025-05-04 21:23:04,531 - pycomo - INFO - Processed 98.12% of find loops steps
# 2025-05-04 21:23:05,731 - pycomo - INFO - Processed 98.35% of find loops steps
# 2025-05-04 21:23:06,991 - pycomo - INFO - Processed 98.58% of find loops steps
# 2025-05-04 21:23:08,053 - pycomo - INFO - Processed 98.81% of find loops steps
# 2025-05-04 21:23:09,109 - pycomo - INFO - Processed 99.03% of find loops steps
# 2025-05-04 21:23:10,465 - pycomo - INFO - Processed 99.26% of find loops steps
# 2025-05-04 21:23:11,765 - pycomo - INFO - Processed 99.49% of find loops steps
# 2025-05-04 21:23:13,158 - pycomo - INFO - Processed 99.72% of find loops steps
# 2025-05-04 21:23:14,584 - pycomo - INFO - Processed 99.95% of find loops steps
# 2025-05-04 21:23:14,648 - pycomo - INFO - Repeating failed find loops steps for reactions: ['Pc__12PPD_Stex']
# 2025-05-04 21:23:15,024 - pycomo - INFO - Processed 100.0% of find loops steps
# 2025-05-04 21:23:15,026 - pycomo - ERROR - Find loops failed for several reactions:
# []
# 2025-05-04 21:23:15,030 - pycomo - INFO - Running single core FVA fallback for reactions []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 fva = Model.run_fva(reactions=Model.model.reactions, fraction_of_optimum=0.9, loopless=True, processes=4)
#       4 # Save to Excel
#       5 fva.to_excel(r"C:\Users\incha\MTdata\Indian_Community\PLM_loopless_FVA.xlsx")
#
# File ~\anaconda3\Lib\site-packages\pycomo\pycomo_models.py:1899, in CommunityModel.run_fva(self, fraction_of_optimum, composition_agnostic, loopless, fva_mu_c, only_exchange_reactions, reactions, verbose, processes)
#    1897     else:
#    1898         logger.debug(f"Running loopless FVA")
# -> 1899     solution_df = self.loopless_fva(reactions,
#    1900                                     fraction_of_optimum=fraction_of_optimum,
#    1901                                     use_loop_reactions_for_ko=True,
#    1902                                     verbose=verbose,
#    1903                                     processes=processes)
#    1904 else:
#    1905     if verbose:
#
# File ~\anaconda3\Lib\site-packages\pycomo\pycomo_models.py:1744, in CommunityModel.loopless_fva(self, reaction_ids, fraction_of_optimum, use_loop_reactions_for_ko, ko_candidate_ids, verbose, processes)
#    1737 def loopless_fva(self,
#    1738                  reaction_ids,
#    1739                  fraction_of_optimum=None,
#    (...)
#    1742                  verbose=False,
#    1743                  processes=None):
# -> 1744     return loopless_fva(self,
#    1745                         reaction_ids,
#    1746                         fraction_of_optimum=fraction_of_optimum,
#    1747                         use_loop_reactions_for_ko=use_loop_reactions_for_ko,
#    1748                         ko_candidate_ids=ko_candidate_ids,
#    1749                         verbose=verbose,
#    1750                         processes=processes)
#
# File ~\anaconda3\Lib\site-packages\pycomo\helper\multiprocess.py:235, in loopless_fva(pycomo_model, reactions, fraction_of_optimum, use_loop_reactions_for_ko, ko_candidate_ids, verbose, processes, time_out, max_time_out)
#     233 else:
#     234     logger.debug("Searching for reactions that are part of loops")
# --> 235 ko_candidate_ids = list(pycomo_model.get_loops(processes=processes)["reaction"])
#     236 if verbose:
#     237     logger.info(f"Search complete. {len(ko_candidate_ids)} reactions found in loops. Proceeding with FVA.")
#
# File ~\anaconda3\Lib\site-packages\pycomo\pycomo_models.py:1033, in CommunityModel.get_loops(self, processes)
#    1030 self.model.medium = no_medium
#    1032 with self.model:
# -> 1033     solution_df = find_loops_in_model(self.convert_to_model_without_fraction_metabolites(), processes=processes)
#    1035 self.medium = original_medium
#    1036 self.apply_medium()
#
# File ~\anaconda3\Lib\site-packages\pycomo\helper\utils.py:706, in find_loops_in_model(model, processes, time_out, max_time_out)
#     704 # Single core fallback
#     705 logger.info(f"Running single core FVA fallback for reactions {failed_tasks}")
# --> 706 for rxn_id, max_flux, min_flux in map(_find_loop_step, reaction_ids):
#     707     processed_rxns += 1
#     708     if processed_rxns % 10 == 0 or processed_rxns == len(reaction_ids):
#
# File ~\anaconda3\Lib\site-packages\pycomo\helper\utils.py:627, in _find_loop_step(rxn_id)
#     626 def _find_loop_step(rxn_id):
# --> 627     rxn = _model.reactions.get_by_id(rxn_id)
#     628     _model.objective = rxn.id
#     629     solution = _model.optimize("minimize")
#
# NameError: name '_model' is not defined

# %%
import pandas as pd
Exchange= Model.potential_metabolite_exchanges()
# Save to Excel
Exchange.to_excel(r"C:\Users\incha\MTdata\Indian_Community\PLM_exchange.xlsx")
