# %%
#Setting up PyCoMo
#Install PyCoMo using pip or conda first in suitable conda environment (mine is in base environment) using anaconda prompt 
#we are going to import all the packages we need.
from pathlib import Path
import sys
import cobra
import os

# %%
#Importing PyCoMo
#As PyCoMo is currently only available as a local package, the direct path to the package directory needs to be used on import.
path_root = r"C:\Users\incha\anaconda3\Lib\site-packages\pycomo\__init__.py"  # Change path according to your PyCoMo location
sys.path.append(str(path_root))
import pycomo
pycomo.configure_logger(level="info")
# Out:
# 2025-05-04 19:40:27,056 - pycomo - INFO - Logger initialized.
# 2025-05-04 19:40:27,064 - pycomo - INFO - Process Pool Logger initialized.
# 2025-05-04 19:40:27,066 - pycomo - INFO - Utils Logger initialized.
# 2025-05-04 19:40:27,072 - pycomo - INFO - Multiprocess Logger initialized.
# 2025-05-04 19:40:27,075 - pycomo - INFO - Log level set to info

# %%
# create two cobra models from sbml (change the path according to where the models are located)
Fp = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\FP_AHD_Medium.xml")
Pc = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\PC_AHD_Medium.xml")
Ms = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\MS_AHD_Medium.xml")
#Lr = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\LR_AHD_Medium.xml")

# create Single Organism Models from cobra models
FP = pycomo.SingleOrganismModel(Fp, "Fp")
PC = pycomo.SingleOrganismModel(Pc, "Pc")
MS = pycomo.SingleOrganismModel(Ms, "Ms")
#LR = pycomo.SingleOrganismModel(Lr, "Lr")

# create Community Model from Single Organism Models
Model = pycomo.CommunityModel([FP, PC, MS], name = "FPM_community")
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2660067
# Academic license 2660067 - for non-commercial use only - registered to t2___@students.iitmandi.ac.in
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp2slaw4_t.lp
# Reading time = 0.01 seconds
# : 953 rows, 2092 columns, 8886 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp_d8f3ov5.lp
# Reading time = 0.04 seconds
# : 1621 rows, 3724 columns, 12098 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpkh29noiy.lp
# Reading time = 0.02 seconds
# : 743 rows, 1380 columns, 5986 nonzeros

# %%
Model.model
# Out:
# 2025-05-04 19:41:28,012 - pycomo - INFO - No community model generated yet. Generating now:
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpezsjay5r.lp
# Reading time = 0.03 seconds
# : 953 rows, 2092 columns, 8886 nonzeros
# 2025-05-04 19:41:30,970 - pycomo - INFO - Identified biomass reaction from objective: bio1
# 2025-05-04 19:41:30,970 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpw9tc3qhi.lp
# Reading time = 0.03 seconds
# : 1621 rows, 3724 columns, 12098 nonzeros
# 2025-05-04 19:41:49,744 - pycomo - INFO - Identified biomass reaction from objective: biomass525
# 2025-05-04 19:41:49,744 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp1dt2k_ln.lp
# Reading time = 0.08 seconds
# : 5016 rows, 10512 columns, 31650 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpxcqq_uxx.lp
# Reading time = 0.02 seconds
# : 743 rows, 1380 columns, 5986 nonzeros
# 2025-05-04 19:42:50,948 - pycomo - INFO - Identified biomass reaction from objective: biomass537
# 2025-05-04 19:42:50,950 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp6w5200ju.lp
# Reading time = 0.04 seconds
# : 1877 rows, 3646 columns, 12602 nonzeros
# 2025-05-04 19:43:10,001 - pycomo - WARNING - Not all reactions in the model are mass and charge balanced. To check which reactions are imbalanced, please run the get_unbalanced_reactions method of this CommunityModel object
# 2025-05-04 19:43:10,001 - pycomo - INFO - Generated community model.
# <Model FPM_community at 0x208fdf60fb0>

# %%
Model.convert_to_fixed_abundance()
abundances = {"Fp": 0.131, "Pc": 0.391, "Ms": 4.57E-05,}
# Apply the abundances
Model.apply_fixed_abundance(abundances)
# Out:
# 2025-05-04 19:43:19,032 - pycomo - WARNING - Warning: Abundances do not sum up to 1. Correction will be applied: {'Fp': 0.131, 'Pc': 0.391, 'Ms': 4.57e-05}
# 2025-05-04 19:43:19,033 - pycomo - INFO - Correction applied. New abundances are:
# {'Fp': 0.250935885498147, 'Pc': 0.7489765742730952, 'Ms': 8.754022875775051e-05}

# %%
Model.summary()
# Out:
# <h3>Objective</h3><p>1.0 community_biomass = 17.48088873432676</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>_26dap_M_medium</td>
#       <td>EX__26dap_M_medium</td>
#       <td>0.1097</td>
#       <td>7</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>_4hbz_medium</td>
#       <td>EX__4hbz_medium</td>
#       <td>0.01358</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>_7a_czp_medium</td>
#       <td>EX__7a_czp_medium</td>
#       <td>152.6</td>
#       <td>15</td>
#       <td>49.89%</td>
#     </tr>
#     <tr>
#       <td>ade_medium</td>
#       <td>EX_ade_medium</td>
#       <td>1.115</td>
#       <td>5</td>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <td>adn_medium</td>
#       <td>EX_adn_medium</td>
#       <td>3.951</td>
#       <td>10</td>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <td>alagln_medium</td>
#       <td>EX_alagln_medium</td>
#       <td>1.49</td>
#       <td>8</td>
#       <td>0.26%</td>
#     </tr>
#     <tr>
#       <td>alahis_medium</td>
#       <td>EX_alahis_medium</td>
#       <td>0.0001417</td>
#       <td>9</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>alathr_medium</td>
#       <td>EX_alathr_medium</td>
#       <td>0.9263</td>
#       <td>7</td>
#       <td>0.14%</td>
#     </tr>
#     <tr>
#       <td>anzp_medium</td>
#       <td>EX_anzp_medium</td>
#       <td>0.02251</td>
#       <td>15</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>arg_L_medium</td>
#       <td>EX_arg_L_medium</td>
#       <td>1.082</td>
#       <td>6</td>
#       <td>0.14%</td>
#     </tr>
#     <tr>
#       <td>asn_L_medium</td>
#       <td>EX_asn_L_medium</td>
#       <td>0.881</td>
#       <td>4</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>asp_L_medium</td>
#       <td>EX_asp_L_medium</td>
#       <td>0.06581</td>
#       <td>4</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>ca2_medium</td>
#       <td>EX_ca2_medium</td>
#       <td>0.1158</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cgly_medium</td>
#       <td>EX_cgly_medium</td>
#       <td>0.01358</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>chor_medium</td>
#       <td>EX_chor_medium</td>
#       <td>0.0004906</td>
#       <td>10</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_medium</td>
#       <td>EX_cl_medium</td>
#       <td>0.1158</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_medium</td>
#       <td>EX_cobalt2_medium</td>
#       <td>0.1158</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_medium</td>
#       <td>EX_cu2_medium</td>
#       <td>0.1158</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cys_L_medium</td>
#       <td>EX_cys_L_medium</td>
#       <td>0.3612</td>
#       <td>3</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>cytd_medium</td>
#       <td>EX_cytd_medium</td>
#       <td>53.03</td>
#       <td>9</td>
#       <td>10.40%</td>
#     </tr>
#     <tr>
#       <td>dad_2_medium</td>
#       <td>EX_dad_2_medium</td>
#       <td>0.1538</td>
#       <td>10</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>dcyt_medium</td>
#       <td>EX_dcyt_medium</td>
#       <td>7.753</td>
#       <td>9</td>
#       <td>1.52%</td>
#     </tr>
#     <tr>
#       <td>dgsn_medium</td>
#       <td>EX_dgsn_medium</td>
#       <td>0.1538</td>
#       <td>10</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>fe2_medium</td>
#       <td>EX_fe2_medium</td>
#       <td>0.1294</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_medium</td>
#       <td>EX_fe3_medium</td>
#       <td>0.1158</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fol_medium</td>
#       <td>EX_fol_medium</td>
#       <td>0.04075</td>
#       <td>19</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>gam_medium</td>
#       <td>EX_gam_medium</td>
#       <td>0.515</td>
#       <td>6</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>glu_L_medium</td>
#       <td>EX_glu_L_medium</td>
#       <td>34.55</td>
#       <td>5</td>
#       <td>3.77%</td>
#     </tr>
#     <tr>
#       <td>glyasn_medium</td>
#       <td>EX_glyasn_medium</td>
#       <td>0.0003591</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glyc3p_medium</td>
#       <td>EX_glyc3p_medium</td>
#       <td>4.465</td>
#       <td>3</td>
#       <td>0.29%</td>
#     </tr>
#     <tr>
#       <td>glycys_medium</td>
#       <td>EX_glycys_medium</td>
#       <td>0.0001273</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glygln_medium</td>
#       <td>EX_glygln_medium</td>
#       <td>0.1483</td>
#       <td>7</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>glyleu_medium</td>
#       <td>EX_glyleu_medium</td>
#       <td>2.021</td>
#       <td>8</td>
#       <td>0.35%</td>
#     </tr>
#     <tr>
#       <td>gsn_medium</td>
#       <td>EX_gsn_medium</td>
#       <td>1.73</td>
#       <td>10</td>
#       <td>0.38%</td>
#     </tr>
#     <tr>
#       <td>h2_medium</td>
#       <td>EX_h2_medium</td>
#       <td>0.06196</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>his_L_medium</td>
#       <td>EX_his_L_medium</td>
#       <td>0.3477</td>
#       <td>6</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>ile_L_medium</td>
#       <td>EX_ile_L_medium</td>
#       <td>1.434</td>
#       <td>6</td>
#       <td>0.19%</td>
#     </tr>
#     <tr>
#       <td>indole_medium</td>
#       <td>EX_indole_medium</td>
#       <td>8.441E-05</td>
#       <td>8</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ins_medium</td>
#       <td>EX_ins_medium</td>
#       <td>35</td>
#       <td>10</td>
#       <td>7.63%</td>
#     </tr>
#     <tr>
#       <td>k_medium</td>
#       <td>EX_k_medium</td>
#       <td>0.1158</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>lys_L_medium</td>
#       <td>EX_lys_L_medium</td>
#       <td>5.619</td>
#       <td>6</td>
#       <td>0.74%</td>
#     </tr>
#     <tr>
#       <td>met_L_medium</td>
#       <td>EX_met_L_medium</td>
#       <td>3.427</td>
#       <td>5</td>
#       <td>0.37%</td>
#     </tr>
#     <tr>
#       <td>metala_medium</td>
#       <td>EX_metala_medium</td>
#       <td>0.5742</td>
#       <td>8</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <td>mg2_medium</td>
#       <td>EX_mg2_medium</td>
#       <td>0.1158</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_medium</td>
#       <td>EX_mn2_medium</td>
#       <td>0.1158</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mqn7_medium</td>
#       <td>EX_mqn7_medium</td>
#       <td>0.02717</td>
#       <td>46</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>nac_medium</td>
#       <td>EX_nac_medium</td>
#       <td>0.02716</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_medium</td>
#       <td>EX_o2_medium</td>
#       <td>283.5</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ocdca_medium</td>
#       <td>EX_ocdca_medium</td>
#       <td>0.3737</td>
#       <td>18</td>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <td>phe_L_medium</td>
#       <td>EX_phe_L_medium</td>
#       <td>0.6778</td>
#       <td>9</td>
#       <td>0.13%</td>
#     </tr>
#     <tr>
#       <td>pheme_medium</td>
#       <td>EX_pheme_medium</td>
#       <td>0.01358</td>
#       <td>34</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>pi_medium</td>
#       <td>EX_pi_medium</td>
#       <td>17.95</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pnto_R_medium</td>
#       <td>EX_pnto_R_medium</td>
#       <td>0.02718</td>
#       <td>9</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>pro_L_medium</td>
#       <td>EX_pro_L_medium</td>
#       <td>0.809</td>
#       <td>5</td>
#       <td>0.09%</td>
#     </tr>
#     <tr>
#       <td>ptrc_medium</td>
#       <td>EX_ptrc_medium</td>
#       <td>0.01358</td>
#       <td>4</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pydx_medium</td>
#       <td>EX_pydx_medium</td>
#       <td>0.1158</td>
#       <td>8</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>

# %%
Model.model.optimize()
# Out:
# <Solution 17.481 at 0x2089a064d40>

# %%
Model.save(r"C:\Users\incha\MTdata\Indian_Community\FPM.xml")
