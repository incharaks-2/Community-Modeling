# %%
#Setting up PyCoMo
#Install PyCoMo using pip or conda first in suitable conda environment (mine is in base environment) using anaconda prompt 
#we are going to import all the packages we need.
from pathlib import Path
import sys
import cobra
import os

# %%
#Importing PyCoMo
#As PyCoMo is currently only available as a local package, the direct path to the package directory needs to be used on import.
path_root = r"C:\Users\incha\anaconda3\Lib\site-packages\pycomo\__init__.py"  # Change path according to your PyCoMo location
sys.path.append(str(path_root))
import pycomo
pycomo.configure_logger(level="info")
# Out:
# 2025-05-04 19:46:12,381 - pycomo - INFO - Logger initialized.
# 2025-05-04 19:46:12,393 - pycomo - INFO - Process Pool Logger initialized.
# 2025-05-04 19:46:12,396 - pycomo - INFO - Utils Logger initialized.
# 2025-05-04 19:46:12,403 - pycomo - INFO - Multiprocess Logger initialized.
# 2025-05-04 19:46:12,406 - pycomo - INFO - Log level set to info

# %%
# create two cobra models from sbml (change the path according to where the models are located)
Fp = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\FP_AHD_Medium.xml")
Pc = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\PC_AHD_Medium.xml")
Ms = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\MS_AHD_Medium.xml")
Lr = cobra.io.read_sbml_model(r"C:\Users\incha\MTdata\Indian_Community\LR_AHD_Medium.xml")

# create Single Organism Models from cobra models
FP = pycomo.SingleOrganismModel(Fp, "Fp")
PC = pycomo.SingleOrganismModel(Pc, "Pc")
MS = pycomo.SingleOrganismModel(Ms, "Ms")
LR = pycomo.SingleOrganismModel(Lr, "Lr")

# create Community Model from Single Organism Models
Model = pycomo.CommunityModel([FP, PC, MS, LR], name = "FPLM_community")
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2660067
# Academic license 2660067 - for non-commercial use only - registered to t2___@students.iitmandi.ac.in
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpeqcyeqky.lp
# Reading time = 0.01 seconds
# : 953 rows, 2092 columns, 8886 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpdftg3cyr.lp
# Reading time = 0.02 seconds
# : 1621 rows, 3724 columns, 12098 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpdr81uezd.lp
# Reading time = 0.02 seconds
# : 743 rows, 1380 columns, 5986 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp1b3heukl.lp
# Reading time = 0.04 seconds
# : 1312 rows, 2582 columns, 11182 nonzeros

# %%
Model.model
# Out:
# 2025-05-04 19:47:26,516 - pycomo - INFO - No community model generated yet. Generating now:
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmplb_tvj2e.lp
# Reading time = 0.02 seconds
# : 953 rows, 2092 columns, 8886 nonzeros
# 2025-05-04 19:47:30,065 - pycomo - INFO - Identified biomass reaction from objective: bio1
# 2025-05-04 19:47:30,065 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpsmpbt7dw.lp
# Reading time = 0.03 seconds
# : 1621 rows, 3724 columns, 12098 nonzeros
# 2025-05-04 19:47:48,793 - pycomo - INFO - Identified biomass reaction from objective: biomass525
# 2025-05-04 19:47:48,793 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpzsm09g51.lp
# Reading time = 0.09 seconds
# : 5016 rows, 10512 columns, 31650 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpi583te4t.lp
# Reading time = 0.09 seconds
# : 743 rows, 1380 columns, 5986 nonzeros
# 2025-05-04 19:48:51,227 - pycomo - INFO - Identified biomass reaction from objective: biomass537
# 2025-05-04 19:48:51,227 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpj_decagz.lp
# Reading time = 0.04 seconds
# : 1877 rows, 3646 columns, 12602 nonzeros
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmp527j838j.lp
# Reading time = 0.03 seconds
# : 1312 rows, 2582 columns, 11182 nonzeros
# 2025-05-04 19:49:10,933 - pycomo - INFO - Identified biomass reaction from objective: bio1
# 2025-05-04 19:49:10,934 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpe6xxbzql.lp
# Reading time = 0.11 seconds
# : 3335 rows, 6628 columns, 23048 nonzeros
# 2025-05-04 19:49:53,154 - pycomo - WARNING - Warning: not wrongly formatted metabolite formula in metabolites of reaction Lr_HMR_9520_Lr_c
# 2025-05-04 19:49:53,201 - pycomo - WARNING - Not all reactions in the model are mass and charge balanced. To check which reactions are imbalanced, please run the get_unbalanced_reactions method of this CommunityModel object
# 2025-05-04 19:49:53,201 - pycomo - INFO - Generated community model.
# <Model FPLM_community at 0x256f90f1190>

# %%
Model.convert_to_fixed_abundance()
abundances = {"Fp": 0.131, "Pc": 0.391,"Ms": 4.57E-05, "Lr":0.002938}
# Apply the abundances
Model.apply_fixed_abundance(abundances)
# Out:
# 2025-05-04 19:50:05,367 - pycomo - WARNING - Warning: Abundances do not sum up to 1. Correction will be applied: {'Fp': 0.131, 'Pc': 0.391, 'Ms': 4.57e-05, 'Lr': 0.002938}
# 2025-05-04 19:50:05,367 - pycomo - INFO - Correction applied. New abundances are:
# {'Fp': 0.24953155688452802, 'Pc': 0.744785028563744, 'Ms': 8.705032175284679e-05, 'Lr': 0.00559636422997514}

# %%
Model.summary()
# Out:
# <h3>Objective</h3><p>1.0 community_biomass = 17.480888734326726</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>_26dap_M_medium</td>
#       <td>EX__26dap_M_medium</td>
#       <td>0.1091</td>
#       <td>7</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>_4hbz_medium</td>
#       <td>EX__4hbz_medium</td>
#       <td>0.01351</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>_7a_czp_medium</td>
#       <td>EX__7a_czp_medium</td>
#       <td>151.7</td>
#       <td>15</td>
#       <td>49.71%</td>
#     </tr>
#     <tr>
#       <td>acald_medium</td>
#       <td>EX_acald_medium</td>
#       <td>0.3011</td>
#       <td>2</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>ade_medium</td>
#       <td>EX_ade_medium</td>
#       <td>0.7871</td>
#       <td>5</td>
#       <td>0.09%</td>
#     </tr>
#     <tr>
#       <td>adn_medium</td>
#       <td>EX_adn_medium</td>
#       <td>3.929</td>
#       <td>10</td>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <td>alagln_medium</td>
#       <td>EX_alagln_medium</td>
#       <td>1.626</td>
#       <td>8</td>
#       <td>0.28%</td>
#     </tr>
#     <tr>
#       <td>alahis_medium</td>
#       <td>EX_alahis_medium</td>
#       <td>0.0001409</td>
#       <td>9</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>alathr_medium</td>
#       <td>EX_alathr_medium</td>
#       <td>0.9211</td>
#       <td>7</td>
#       <td>0.14%</td>
#     </tr>
#     <tr>
#       <td>arg_L_medium</td>
#       <td>EX_arg_L_medium</td>
#       <td>1.076</td>
#       <td>6</td>
#       <td>0.14%</td>
#     </tr>
#     <tr>
#       <td>asn_L_medium</td>
#       <td>EX_asn_L_medium</td>
#       <td>0.8957</td>
#       <td>4</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>asp_L_medium</td>
#       <td>EX_asp_L_medium</td>
#       <td>0.3036</td>
#       <td>4</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>ca2_medium</td>
#       <td>EX_ca2_medium</td>
#       <td>0.1155</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cgly_medium</td>
#       <td>EX_cgly_medium</td>
#       <td>0.01381</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>chor_medium</td>
#       <td>EX_chor_medium</td>
#       <td>0.0004879</td>
#       <td>10</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_medium</td>
#       <td>EX_cl_medium</td>
#       <td>0.1155</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_medium</td>
#       <td>EX_cobalt2_medium</td>
#       <td>0.1155</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>csn_medium</td>
#       <td>EX_csn_medium</td>
#       <td>0.02043</td>
#       <td>4</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_medium</td>
#       <td>EX_cu2_medium</td>
#       <td>0.1155</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cys_L_medium</td>
#       <td>EX_cys_L_medium</td>
#       <td>0.3645</td>
#       <td>3</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>cytd_medium</td>
#       <td>EX_cytd_medium</td>
#       <td>52.73</td>
#       <td>9</td>
#       <td>10.36%</td>
#     </tr>
#     <tr>
#       <td>dad_2_medium</td>
#       <td>EX_dad_2_medium</td>
#       <td>0.1529</td>
#       <td>10</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>dcyt_medium</td>
#       <td>EX_dcyt_medium</td>
#       <td>7.71</td>
#       <td>9</td>
#       <td>1.52%</td>
#     </tr>
#     <tr>
#       <td>dgsn_medium</td>
#       <td>EX_dgsn_medium</td>
#       <td>0.1529</td>
#       <td>10</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>fcsn_medium</td>
#       <td>EX_fcsn_medium</td>
#       <td>0.2653</td>
#       <td>4</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>fe2_medium</td>
#       <td>EX_fe2_medium</td>
#       <td>0.1296</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_medium</td>
#       <td>EX_fe3_medium</td>
#       <td>0.1152</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fol_medium</td>
#       <td>EX_fol_medium</td>
#       <td>0.04143</td>
#       <td>19</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>gam_medium</td>
#       <td>EX_gam_medium</td>
#       <td>0.5121</td>
#       <td>6</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>glu_L_medium</td>
#       <td>EX_glu_L_medium</td>
#       <td>34.43</td>
#       <td>5</td>
#       <td>3.76%</td>
#     </tr>
#     <tr>
#       <td>glyasn_medium</td>
#       <td>EX_glyasn_medium</td>
#       <td>0.0003571</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glyc3p_medium</td>
#       <td>EX_glyc3p_medium</td>
#       <td>4.548</td>
#       <td>3</td>
#       <td>0.30%</td>
#     </tr>
#     <tr>
#       <td>glycys_medium</td>
#       <td>EX_glycys_medium</td>
#       <td>0.0001266</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glygln_medium</td>
#       <td>EX_glygln_medium</td>
#       <td>0.003584</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glyleu_medium</td>
#       <td>EX_glyleu_medium</td>
#       <td>2.055</td>
#       <td>8</td>
#       <td>0.36%</td>
#     </tr>
#     <tr>
#       <td>glymet_medium</td>
#       <td>EX_glymet_medium</td>
#       <td>0.5268</td>
#       <td>7</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>glytyr_medium</td>
#       <td>EX_glytyr_medium</td>
#       <td>0.01181</td>
#       <td>11</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>gsn_medium</td>
#       <td>EX_gsn_medium</td>
#       <td>1.72</td>
#       <td>10</td>
#       <td>0.38%</td>
#     </tr>
#     <tr>
#       <td>gua_medium</td>
#       <td>EX_gua_medium</td>
#       <td>0.01461</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2_medium</td>
#       <td>EX_h2_medium</td>
#       <td>0.06161</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>his_L_medium</td>
#       <td>EX_his_L_medium</td>
#       <td>0.3535</td>
#       <td>6</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>ile_L_medium</td>
#       <td>EX_ile_L_medium</td>
#       <td>1.458</td>
#       <td>6</td>
#       <td>0.19%</td>
#     </tr>
#     <tr>
#       <td>indole_medium</td>
#       <td>EX_indole_medium</td>
#       <td>8.393E-05</td>
#       <td>8</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ins_medium</td>
#       <td>EX_ins_medium</td>
#       <td>34.81</td>
#       <td>10</td>
#       <td>7.60%</td>
#     </tr>
#     <tr>
#       <td>k_medium</td>
#       <td>EX_k_medium</td>
#       <td>0.1155</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>kestopt_medium</td>
#       <td>EX_kestopt_medium</td>
#       <td>0.3617</td>
#       <td>30</td>
#       <td>0.24%</td>
#     </tr>
#     <tr>
#       <td>lys_L_medium</td>
#       <td>EX_lys_L_medium</td>
#       <td>5.588</td>
#       <td>6</td>
#       <td>0.73%</td>
#     </tr>
#     <tr>
#       <td>malthx_medium</td>
#       <td>EX_malthx_medium</td>
#       <td>0.09869</td>
#       <td>36</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>met_L_medium</td>
#       <td>EX_met_L_medium</td>
#       <td>3.408</td>
#       <td>5</td>
#       <td>0.37%</td>
#     </tr>
#     <tr>
#       <td>metala_medium</td>
#       <td>EX_metala_medium</td>
#       <td>0.05962</td>
#       <td>8</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>mg2_medium</td>
#       <td>EX_mg2_medium</td>
#       <td>0.1155</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_medium</td>
#       <td>EX_mn2_medium</td>
#       <td>0.1155</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mqn7_medium</td>
#       <td>EX_mqn7_medium</td>
#       <td>0.02762</td>
#       <td>46</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>nac_medium</td>
#       <td>EX_nac_medium</td>
#       <td>0.02761</td>
#       <td>6</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_medium</td>
#       <td>EX_o2_medium</td>
#       <td>281.9</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ocdca_medium</td>
#       <td>EX_ocdca_medium</td>
#       <td>0.3716</td>
#       <td>18</td>
#       <td>0.15%</td>

# %%
Model.model.optimize()
# Out:
# <Solution 17.481 at 0x2568cb1f890>

# %%
Model.save(r"C:\Users\incha\MTdata\Indian_Community\FPLM.xml")

# %%
import pandas as pd
fva = Model.run_fva(reactions=Model.model.reactions, fraction_of_optimum=0.9, loopless=True, processes=4)

# Save to Excel
fva.to_excel(r"C:\Users\incha\MTdata\Indian_Community\FPLM_loopless_FVA.xlsx")
# Out:
# Read LP format model from file C:\Users\incha\AppData\Local\Temp\tmpaezkl0zh.lp
# Reading time = 0.21 seconds
# : 12557 rows, 25638 columns, 85144 nonzeros

# %%
import pandas as pd
Exchange= Model.potential_metabolite_exchanges()
# Save to Excel
Exchange.to_excel(r"C:\Users\incha\MTdata\Indian_Community\FPLM_exchange.xlsx")
